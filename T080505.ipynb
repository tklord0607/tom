# %%
import requests
def getNames():
    times = 3
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)
    #print(type(cnames[0]))
    #names = cnames[0].split('、')
    return names


names = getNames()

# %%
#使用"、"符號,連結3個陣列元素
names_str = "、".join(names)
names_list = names_str.split("、") #有299筆的list
newLine_name = "\n".join(names_list)  #有換行符號的字串
print(newLine_name)
# Out:
# 李筱雯
# 林雅如
# 陳永淑
# 涂靜宜
# 陳郁行
# 陳家蓮
# 陳依薇
# 汪筱宏
# 陳京季
# 藍淑華
# 黃雅筑
# 姜伊榮
# 陳玫婷
# 楊丞海
# 陳家豪
# 黃雯妹
# 黎佳芳
# 陳俊洋
# 黃玉白
# 倪其琬
# 林卉治
# 李宇芝
# 劉曉雯
# 鄧水恆
# 李紀陽
# 鄭群鴻
# 張哲火
# 張家芝
# 林俞琦
# 洪俊傑
# 林紀毓
# 林欣彬
# 林政幸
# 張曉軍
# 陳志樺
# 鄭惠丞
# 張漢天
# 李俊智
# 王元定
# 吳承士
# 楊旭茜
# 陳秋仁
# 潘雅玲
# 黃偉海
# 廖家秀
# 黃雪綠
# 李恆雅
# 楊羿達
# 鄭學潔
# 李山季
# 鄭岱鈺
# 丁凱倫
# 沈欣勇
# 林婉婷
# 陳永亨
# 錢淑芳
# 劉怡如
# 黃宜芳
# 陳瑩吉
# 郭于珊
# 張憶念
# 溫盛行
# 張昌寶
# 陳慧安
# 陳如慈
# 蔡海緯
# 梁如妍
# 吳佳霖
# 周育德
# 陳虹陽
# 黃宗憲
# 陳惠君
# 張旺昆
# 陳美靖
# 劉海喜
# 牛俊逸
# 林佳容
# 滑嘉玲
# 劉偉哲
# 李鎮宇
# 張建宏
# 蔡弘恩
# 林宛南
# 趙筱雯
# 許宛玲
# 張韻輝
# 杜國紹
# 張雅佩
# 蔡嬌芳
# 孫璇延
# 林東盈
# 蘇孟雯
# 林正福
# 李采桓
# 蕭群啟
# 郭名中
# 張珍男
# 鄭宜君
# 許兆季
# 李承茜
# 吳子軒
# 方仲康
# 黃文花
# 李蘭雯
# 杭少妃
# 陳巧火
# 張玟君
# 張雅俊
# 簡軍佐
# 井惠玲
# 陳呈州
# 林均瑞
# 陳逸奇
# 陳致甫
# 林萬妤
# 戴豪凌
# 宋文婷
# 蔡家祥
# 曹�琝B
# 王宜潔
# 黃國娥
# 余宇劭
# 陳鈺婷
# 賴淑玲
# 郭怡伶
# 梁妍堅
# 黃建誠
# 李彥洋
# 吳美茹
# 陳宥南
# 耿靜怡
# 米善茹
# 張長霞
# 吳欣怡
# 吳佩易
# 林冠容
# 蔡�痟f
# 邱睿誠
# 王彥翔
# 駱鳳丞
# 張偉哲
# 杜鎮瑄
# 許志臻
# 郭健岑
# 徐莉雯
# 余彥青
# 吳易帆
# 衡珊郁
# 吳郁涵
# 賴侑寶
# 史�琲漶B姚必卿
# 許俊賢
# 楊寶英
# 錢佳宏
# 楊有群
# 林家瑋
# 鄭伊宸
# 李典志
# 張珍旺
# 林士瑋
# 吳重昌
# 陳佩原
# 蔡盛揚
# 周玟沛
# 陳佳芬
# 蔡玉芳
# 蘇慧萍
# 吳淑君
# 張宇雄
# 林容如
# 吳佳玲
# 陳秋綸
# 趙惠瑄
# 蔡佳亦
# 阮建豪
# 楊如恩
# 吳冠宏
# 黃玉琬
# 劉秀美
# 黃琬婷
# 彭舒涵
# 王玉鳳
# 吳柏剛
# 袁石杰
# 穆成欣
# 黃于湖
# 陳詩冰
# 金峻豪
# 何芝彥
# 林得昕
# 單建宏
# 張毓和
# 胡立全
# 陳雅綸
# 陳雅琪
# 王文馨
# 林如心
# 謝志俐
# 張彥君
# 蔡志瑋
# 周怡伶
# 李宗修
# 謝婷婷
# 楊志琬
# 李佳欣
# 屠和�琚B彭雅惠
# 許尚奇
# 吳玲禎
# 林志豪
# 王志偉
# 黃怡伶
# 張允泰
# 羅靜如
# 陳瑞祥
# 楊怡君
# 許裕仁
# 鄭淑貞
# 陳俊佑
# 葉懿恬
# 張惟伯
# 張凱瑄
# 劉怡廷
# 陳怡芳
# 王詩旭
# 蔡肇綸
# 楊琦茂
# 黃靖宜
# 陳冠中
# 鄭怡婷
# 張淑君
# 王姿蓉
# 宋志軒
# 侯惠敏
# 涂至松
# 林佑蓁
# 林瑤峰
# 呂逸典
# 曹佳雯
# 陳佩芳
# 朱佩君
# 陳協鑫
# 宋弘芃
# 舒雅如
# 許志俊
# 曾淑江
# 劉家育
# 陳乃文
# 李尚郁
# 魏冠儒
# 林易育
# 張宜吉
# 林義英
# 陳哲豪
# 徐靜旺
# 鄭尹紫
# 張海州
# 程慧婷
# 王茂蓉
# 葉子軒
# 周添信
# 陳珮芬
# 羅珍夫
# 林宛臻
# 鄧志宏
# 林信廷
# 孫苡歡
# 黃怡東
# 盧豪倫
# 王莉雯
# 陳柏宇
# 陳芃強
# 吳明桓
# 蔡亮雨
# 楊揚達
# 徐聿宏
# 許家惟
# 李政其
# 賴卓蓉
# 韓建霖
# 廣玉全
# 張雅愛
# 沈奎雅
# 許佳琪
# 黃家慧
# 朱梅妮
# 柯羽恭
# 王坤琳
# 吳育維
# 曹育維
# 蔡宜倩
# 鮑德雅
# 黃玉謙
# 陳意婷
# 吳姿義
# 吳采珠
# 陳小年
# 葛康茹
# 陳羿迪

# %%
with open("T080505names.csv",mode="w",encoding='utf-8',newline="") as file:
    file.write(newLine_name)
