# %%
import ffn
prices = ffn.get('0056.TW,00878.TW', start='2010-01-01')
prices
# Out:
#                0056tw    00878tw
# Date
# 2020-07-10  29.520000  15.000000
# 2020-07-13  29.650000  14.990000
# 2020-07-14  29.580000  14.980000
# 2020-07-15  29.530001  14.960000
# 2020-07-16  29.629999  14.970000
# ...               ...        ...
# 2023-08-14  34.279999  21.049999
# 2023-08-15  34.849998  21.430000
# 2023-08-16  35.139999  21.270000
# 2023-08-17  35.330002  21.320000
# 2023-08-18  34.840000  21.049999
#
# [758 rows x 2 columns]

# %%
ax = prices.rebase().plot(figsize=(10, 5))

# %%
import csv
import pandas as pd
def getStockNames() -> pd.Series:
    with open('codeSearch.csv',encoding='utf-8',newline='') as file:
        next(file)
        csv_reader = csv.reader(file)
        stock_codes = {}
        for item in csv_reader:
            key  =  item[2]
            stock_codes[key] = item[3]
        
    code_series:pd.Series = pd.Series(stock_codes)
    return code_series

getStockNames()
# Out:
# 1101      台泥
# 1102      亞泥
# 1103      嘉泥
# 1104      環泥
# 1108      幸福
#         ...
# 9944      新麗
# 9945     潤泰新
# 9946    三發地產
# 9955      佳龍
# 9958     世紀鋼
# Length: 975, dtype: object
